# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# Initialize the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("LiYuan/amazon-review-sentiment-analysis")
model = AutoModelForSequenceClassification.from_pretrained("LiYuan/amazon-review-sentiment-analysis")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from transformers import AutoTokenizer, AutoModelForSequenceClassification
#       2 import torch
#       4 # Initialize the tokenizer and model
#
# File c:\Users\kaush\OneDrive\Documents\Coding\DormDash\venv\lib\site-packages\transformers\__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      48     logging,
#      49 )
#      52 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File c:\Users\kaush\OneDrive\Documents\Coding\DormDash\venv\lib\site-packages\transformers\dependency_versions_check.py:16
# ...

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import torch
#
# File c:\Users\kaush\OneDrive\Documents\Coding\DormDash\venv\lib\site-packages\torch\__init__.py:533
#     519         raise ImportError(textwrap.dedent('''
#     520             Failed to load PyTorch C extensions:
#     521                 It appears that PyTorch has loaded the `torch/_C` folder
#    (...)
#     529                 or by running Python from a different directory.
#     530             ''').strip()) from None
#     531     raise  # If __file__ is not None the cause is unknown, so just re-raise.
# --> 533 for name in dir(_C):
#     534     if name[0] != '_' and not name.endswith('Base'):
#     535         __all__.append(name)
#
# NameError: name '_C' is not defined

# %%
import pandas as pd

df = pd.read_csv('varying_sentiment_product_reviews_corrected.csv')
df = df[:1000]
df = df[['reviewText']]

star1 = 0
star2 = 0
star3 = 0
star4 = 0
star5 = 0

for text in df['reviewText']:
    # print(runModel(text))
    fstar1, fstar2, fstar3, fstar4, fstar5 = runModel(str(text))
    star1 += fstar1
    star2 += fstar2
    star3 += fstar3
    star4 += fstar4
    star5 += fstar5

    # print(text)

print(star1, star2, star3, star4, star5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 15
#      11 star5 = 0
#      13 for text in df['reviewText']:
#      14     # print(runModel(text))
# ---> 15     fstar1, fstar2, fstar3, fstar4, fstar5 = runModel(str(text))
#      16     star1 += fstar1
#      17     star2 += fstar2
#
# Cell In[2], line 7, in runModel(text)
#       5 # Predict the sentiment
#       6 with torch.no_grad():
# ----> 7     logits = model(**inputs).logits
#       9 # Convert logits to probabilities
#      10 probabilities = torch.softmax(logits, dim=1)
#
# File c:\Users\kaush\OneDrive\Documents\Coding\DormDash\venv\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# ...

# %%
def runModel(text):
    # Tokenize the text
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)

    # Predict the sentiment
    with torch.no_grad():
        logits = model(**inputs).logits

    # Convert logits to probabilities
    probabilities = torch.softmax(logits, dim=1)

    # Assuming the model follows a binary classification where [0] is negative and [1] is positive sentiment
    one_score, two_score, three_score, four_score, five_score = probabilities[0]

    return one_score, two_score, three_score, four_score, five_score

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/LiYuan/amazon-review-sentiment-analysis"
headers = {"Authorization": "Bearer APIKEY"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

output = query({
    "inputs": "I thought the product was ok.",
})
print(output)
# Out:
# [[{'label': '3 stars', 'score': 0.7065303325653076}, {'label': '2 stars', 'score': 0.13546311855316162}, {'label': '4 stars', 'score': 0.11736521869897842}, {'label': '1 star', 'score': 0.028621001169085503}, {'label': '5 stars', 'score': 0.01202035415917635}]]
